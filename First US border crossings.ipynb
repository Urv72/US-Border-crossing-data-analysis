# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Border_Crossing_Entry_Data1.csv',sep=',')

# %%
df
# Out:
#             Port Name         State  Port Code            Border  \
# 0       Calexico East    California       2507  US-Mexico Border
# 1           Van Buren         Maine        108  US-Canada Border
# 2           Otay Mesa    California       2506  US-Mexico Border
# 3             Nogales       Arizona       2604  US-Mexico Border
# 4         Trout River      New York        715  US-Canada Border
# ...               ...           ...        ...               ...
# 346728         Norton       Vermont        211  US-Canada Border
# 346729       Columbus    New Mexico       2406  US-Mexico Border
# 346730       Hansboro  North Dakota       3415  US-Canada Border
# 346731  Calexico East    California       2507  US-Mexico Border
# 346732       Presidio         Texas       2403  US-Mexico Border
#
#                           Date                      Measure  Value  \
# 0       03/01/2019 12:00:00 AM                       Trucks  34447
# ...

# %%
df.groupby('Port Name')['Value'].sum().sort_values(ascending=False)
# Out:
# Port Name
# El Paso                  1151783061
# San Ysidro               1135400899
# Laredo                    653682020
# Hidalgo                   569145367
# Buffalo-Niagara Falls     542713064
#                             ...
# Willow Creek                 142175
# Whitlash                      67608
# Algonac                       63825
# Boquillas                     50461
# Toledo-Sandusky                 373
# Name: Value, Length: 116, dtype: int64

# %%
df.groupby('Port Name')['Value'].sum().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(12,6)).set_title('Port with Highest Border crossing entries')
# Out:
# Text(0.5, 1.0, 'Port with Highest Border crossing entries')

# %%
df.groupby('Port Name')['Value'].sum().sort_values(ascending=False)
# Out:
# Port Name
# El Paso                  1151783061
# San Ysidro               1135400899
# Laredo                    653682020
# Hidalgo                   569145367
# Buffalo-Niagara Falls     542713064
#                             ...
# Willow Creek                 142175
# Whitlash                      67608
# Algonac                       63825
# Boquillas                     50461
# Toledo-Sandusky                 373
# Name: Value, Length: 116, dtype: int64

# %%
df.groupby('Port Name')['Value'].sum().sort_values(ascending=False).tail(10).plot(kind='bar',figsize=(12,6)).set_title('Port with Lowest border crossing entries')
# Out:
# Text(0.5, 1.0, 'Port with Lowest border crossing entries')

# %%
df.groupby('State')['Value'].sum().sort_values(ascending=False)
# Out:
# State
# Texas           3633098966
# California      2499521716
# Arizona          888075092
# New York         827170661
# Michigan         753167571
# Washington       501550846
# Maine            231249782
# Vermont          114257813
# Minnesota         95764039
# North Dakota      75722499
# New Mexico        64936274
# Montana           54160434
# Idaho             20998428
# Alaska            13920348
# Ohio                   373
# Name: Value, dtype: int64

# %%
df.groupby('State')['Value'].sum().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(12,6)).set_title('State in demand among the border crossers')
# Out:
# Text(0.5, 1.0, 'State in demand among the border crossers')

# %%
df.groupby('Border')['Value'].sum().sort_values(ascending=False)
# Out:
# Border
# US-Mexico Border    7085632048
# US-Canada Border    2687962794
# Name: Value, dtype: int64

# %%
df.groupby('Border')['Value'].sum().sort_values(ascending=False).plot(kind='bar').set_title('Border vs Value') # .text(0.3,1,str(v), color='blue', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Border vs Value')

# %%
df['Date']
# Out:
# 0         03/01/2019 12:00:00 AM
# 1         03/01/2019 12:00:00 AM
# 2         03/01/2019 12:00:00 AM
# 3         03/01/2019 12:00:00 AM
# 4         03/01/2019 12:00:00 AM
#                    ...
# 346728    01/01/1996 12:00:00 AM
# 346729    01/01/1996 12:00:00 AM
# 346730    01/01/1996 12:00:00 AM
# 346731    01/01/1996 12:00:00 AM
# 346732    01/01/1996 12:00:00 AM
# Name: Date, Length: 346733, dtype: object

# %%
list1 = df['Date'].to_list()

# %%
for i in range(0,len(list1)):
    list1[i] = list1[i][6:10]

# %%
df['Year'] = list1

# %%
df
# Out:
#             Port Name         State  Port Code            Border  \
# 0       Calexico East    California       2507  US-Mexico Border
# 1           Van Buren         Maine        108  US-Canada Border
# 2           Otay Mesa    California       2506  US-Mexico Border
# 3             Nogales       Arizona       2604  US-Mexico Border
# 4         Trout River      New York        715  US-Canada Border
# ...               ...           ...        ...               ...
# 346728         Norton       Vermont        211  US-Canada Border
# 346729       Columbus    New Mexico       2406  US-Mexico Border
# 346730       Hansboro  North Dakota       3415  US-Canada Border
# 346731  Calexico East    California       2507  US-Mexico Border
# 346732       Presidio         Texas       2403  US-Mexico Border
#
#                           Date                      Measure  Value  \
# 0       03/01/2019 12:00:00 AM                       Trucks  34447
# ...

# %%
df.groupby('Year')['Value'].sum().sort_index()
# Out:
# Year
# 1996    429790351
# 1997    494174198
# 1998    508590704
# 1999    538456724
# 2000    540021542
# 2001    493083902
# 2002    475702818
# 2003    456392653
# 2004    458220298
# 2005    450234268
# 2006    440296022
# 2007    417587175
# 2008    399902033
# 2009    359451762
# 2010    344246536
# 2011    332226000
# 2012    344503916
# 2013    356218438
# 2014    363314116
# 2015    365219998
# 2016    367484183
# 2017    372971276
# 2018    379157530
# 2019     86348399
# Name: Value, dtype: int64

# %%
df.groupby('Year')['Value'].sum().sort_index().plot(kind='bar',figsize=(12,6)).set_title('Border crossing entries Yearwise')
# Out:
# Text(0.5, 1.0, 'Border crossing entries Yearwise')

# %%
df.groupby(['Border','Measure'])['Value'].sum()
# Out:
# Border            Measure
# US-Canada Border  Bus Passengers                   74327495
#                   Buses                             3093613
#                   Pedestrians                      12968574
#                   Personal Vehicle Passengers    1538658810
#                   Personal Vehicles               736044372
#                   Rail Containers Empty            12350707
#                   Rail Containers Full             30461135
#                   Train Passengers                  5909597
#                   Trains                             700993
#                   Truck Containers Empty           24647416
#                   Truck Containers Full           106505603
#                   Trucks                          142294479
# US-Mexico Border  Bus Passengers                   68003376
#                   Buses                             5450143
#                   Pedestrians                    1031249540
# ...

# %%
df.groupby(['Border','Measure'])['Value'].sum().plot(kind='bar',figsize=(12,7)).set_title('Border,Measure vs Value')
# Out:
# Text(0.5, 1.0, 'Border,Measure vs Value')

# %%
df.groupby(['Border','Measure'])['Value'].sum().sort_values(ascending=False)
# Out:
# Border            Measure
# US-Mexico Border  Personal Vehicle Passengers    3918732465
#                   Personal Vehicles              1823646820
# US-Canada Border  Personal Vehicle Passengers    1538658810
# US-Mexico Border  Pedestrians                    1031249540
# US-Canada Border  Personal Vehicles               736044372
#                   Trucks                          142294479
# US-Mexico Border  Trucks                          111359681
# US-Canada Border  Truck Containers Full           106505603
#                   Bus Passengers                   74327495
# US-Mexico Border  Truck Containers Full            70684685
#                   Bus Passengers                   68003376
#                   Truck Containers Empty           39398619
# US-Canada Border  Rail Containers Full             30461135
#                   Truck Containers Empty           24647416
#                   Pedestrians                      12968574
# ...

# %%
df.groupby(['Border','Measure'])['Value'].sum().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(12,6)).set_title('Border,Measure vs Value top 10')
# Out:
# Text(0.5, 1.0, 'Border,Measure vs Value top 10')

# %%
df.groupby(['State','Measure'])['Value'].sum()
# Out:
# State       Measure
# Alaska      Bus Passengers                  3668090
#             Buses                            249674
#             Pedestrians                       46029
#             Personal Vehicle Passengers     5557002
#             Personal Vehicles               2504879
#                                              ...
# Washington  Train Passengers                1385474
#             Trains                            66139
#             Truck Containers Empty          4106420
#             Truck Containers Full           9839889
#             Trucks                         15298380
# Name: Value, Length: 169, dtype: int64

# %%
df.groupby(['State','Measure'])['Value'].sum().sort_values(ascending=False)
# Out:
# State       Measure
# Texas       Personal Vehicle Passengers    2064627838
# California  Personal Vehicle Passengers    1349044241
# Texas       Personal Vehicles               926811032
# California  Personal Vehicles               675236903
# New York    Personal Vehicle Passengers     485498317
#                                               ...
# Alaska      Rail Containers Empty                   0
# New Mexico  Trains                                  0
#             Train Passengers                        0
#             Rail Containers Full                    0
#             Rail Containers Empty                   0
# Name: Value, Length: 169, dtype: int64

# %%
df.groupby(['State','Measure'])['Value'].sum().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(12,6)).set_title('State,Measure vs Value')
# Out:
# Text(0.5, 1.0, 'State,Measure vs Value')

# %%
df['Measure'].value_counts()
# Out:
# Personal Vehicles              30219
# Personal Vehicle Passengers    30196
# Trucks                         29856
# Truck Containers Empty         29757
# Truck Containers Full          29694
# Buses                          28822
# Bus Passengers                 28820
# Pedestrians                    28697
# Trains                         27708
# Rail Containers Empty          27684
# Rail Containers Full           27657
# Train Passengers               27623
# Name: Measure, dtype: int64

# %%
df['Measure'].value_counts().plot(kind='bar',figsize=(12,6)).set_title('Measure vs Value_counts')
# Out:
# Text(0.5, 1.0, 'Measure vs Value_counts')

# %%
df
# Out:
#             Port Name         State  Port Code            Border  \
# 0       Calexico East    California       2507  US-Mexico Border
# 1           Van Buren         Maine        108  US-Canada Border
# 2           Otay Mesa    California       2506  US-Mexico Border
# 3             Nogales       Arizona       2604  US-Mexico Border
# 4         Trout River      New York        715  US-Canada Border
# ...               ...           ...        ...               ...
# 346728         Norton       Vermont        211  US-Canada Border
# 346729       Columbus    New Mexico       2406  US-Mexico Border
# 346730       Hansboro  North Dakota       3415  US-Canada Border
# 346731  Calexico East    California       2507  US-Mexico Border
# 346732       Presidio         Texas       2403  US-Mexico Border
#
#                           Date                      Measure  Value  \
# 0       03/01/2019 12:00:00 AM                       Trucks  34447
# ...

# %%
df.groupby('Location')['Value'].sum().sort_values(ascending=False)
# Out:
# Location
# POINT (-106.45 31.76)                   1064545939
# POINT (-117.03 32.54)                   1039046799
# POINT (-99.51 27.5)                      603766920
# POINT (-98.27 26.1)                      534523111
# POINT (-78.91 42.91)                     505991908
#                                            ...
# POINT (-131.64031 55.33897)                  16349
# POINT (-103.48222 48.95389)                   6328
# POINT (-98.701 48.97029)                      5581
# POINT (-111.24900000000001 48.90372)          3732
# POINT (-83.53303000000001 41.6648)             373
# Name: Value, Length: 224, dtype: int64

# %%
df.groupby('Location')['Value'].sum().sort_values(ascending=False).head(10).plot(kind='bar',figsize=(12,6)).set_title('Location vs Value')
# Out:
# Text(0.5, 1.0, 'Location vs Value')
